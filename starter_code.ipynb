# %%
import quandl
#visualizing: Correlation function (monthly)

# %%
quandl.ApiConfig.api_key = "<ENTER API CODE HERE>"

# %%
data = quandl.get("EOD/AAPL", start_date="2018-01-01", end_date="2019-01-04", collapse="monthly")

# %%
data
# Out:
#                 Open      High     Low   Close      Volume  Dividend  Split  \
# Date
# 2018-01-31  166.8700  168.4417  166.50  167.43  32478930.0       0.0    1.0
# 2018-02-28  179.2600  180.6150  178.05  178.12  37782138.0       0.0    1.0
# 2018-03-31  167.8050  171.7500  166.90  167.78  38398505.0       0.0    1.0
# 2018-04-30  162.1302  167.2600  161.84  165.26  42427424.0       0.0    1.0
# 2018-05-31  187.2200  188.2300  186.14  186.87  27482793.0       0.0    1.0
# 2018-06-30  186.2900  187.1900  182.91  185.11  22737666.0       0.0    1.0
# 2018-07-31  190.3000  192.1400  189.34  190.29  39373038.0       0.0    1.0
# 2018-08-31  226.5100  228.8700  226.00  227.63  43340134.0       0.0    1.0
# 2018-09-30  224.7900  225.8400  224.02  225.74  22929364.0       0.0    1.0
# 2018-10-31  216.8800  220.4500  216.62  218.86  38358933.0       0.0    1.0
# 2018-11-30  180.2900  180.3300  177.03  178.58  39531549.0       0.0    1.0
# ...

# %%
housing = quandl.get('ZILLOW/C537_MSPAH', start_date="2015-01-01", end_date="2016-01-01")

# %%
housing
# Out:
#                    Value
# Date
# 2015-02-28  1.556154e+06
# 2015-03-31  1.526235e+06
# 2015-04-30  1.612950e+06
# 2015-05-31  1.701250e+06
# 2015-06-30  1.696750e+06
# 2015-07-31  1.735000e+06
# 2015-08-31  1.723000e+06
# 2015-09-30  1.687750e+06
# 2015-10-31  1.576500e+06
# 2015-11-30  1.633300e+06
# 2015-12-31  1.668700e+06
