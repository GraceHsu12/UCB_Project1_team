# %% [markdown]
# # Quandl API and export the results into csv file
#
# Format:https://www.quandl.com/api/v3/datatables/{DataProductCode}/{datatable_code}?qopts.export=true&api_key=YOURAPIKEY
#
# * Data product code: WIKI (End of Day US Stock prices)
# * datatable_code for WIKI: PRICES
# * [See this link for data product codes](https://docs.quandl.com/docs/data-organization)
#
# Sample: https://www.quandl.com/api/v3/datatables/WIKI/PRICES?qopts.export=true&api_key=YOURAPIKEY
#
# qopts.export=true --> This code is a csv table exporter, since a call will most likely not be able to grab all the data you want
#
# ##### MAXIMUM 10 bulk downloads with exporter per hour
#
# The generated link to download will only ast for 2 min before it expires. Then you have to perform another API call.

# %% [markdown]
# run this API call to get list of all tickers found in WIKI database:
# https://www.quandl.com/api/v3/databases/WIKI/codes?api_key=YuSp1-_PFQ2BVadMQVtk

# %%
base_url = "https://www.quandl.com/api/v3/datatables/WIKI/Prices?api_key={api_key}&ticker="

# %% [markdown]
# # From Quandl Library: Table call
#
# * Use Quandl library method: .get_table()
#
# import quandl
# quandl.ApiConfig.api_key = "YOURAPIKEY"
# data = quandl.get_table(DataProductCode/Datatable_code, filter = ____, paginate=true)
#
# filters:
# * compnumber
# * mapcode
# * reportdate
#
# paginate=true --> Allows you to exend the limit of rows per call to 1,000,000
#
# Samples:
#
# https://docs.quandl.com/docs/python-tables

# %% [markdown]
# # From Quandl Library: Time Series Call
# import quandl
# quandl.ApiConfig.api_key = "YOURAPIKEY"
#
# data = quandl.get(ZILLOW/{Area_Category}{Area_code}_{IndicatorCode}

# %%
import pandas as pd
import csv

# %%
city_file = open("areas_city.txt", 'r')
city_list = city_file.readlines()
city_list.pop(0)

cities = []
for each in range(len(city_list)):
    # Split each line in text file into a list while removing \n 
    cities.append(city_list[each].strip("\n"))

    

# split the cities list into City, State, Area Code format
cities = [x.split("|") for x in cities]

# %%
for each in cities:
    each[0] = each[0].split(", ")

cities
# Out:
# [[['Aaronsburg', 'PA'], '22759'],
#  [['Abbeville', 'AL'], '4309'],
#  [['Abbeville', 'GA'], '17572'],
#  [['Abbeville', 'LA'], '14615'],
#  [['Abbeville', 'MS'], '16597'],
#  [['Abbeville', 'SC'], '24719'],
#  [['Abbot', 'ME'], '19942'],
#  [['Abbotsford', 'WI'], '6609'],
#  [['Abbott', 'PA'], '20990'],
#  [['Abbottstown', 'PA'], '21077'],
#  [['Abell', 'MD'], '10858'],
#  [['Aberdeen', 'ID'], '23966'],
#  [['Aberdeen', 'MD'], '1554'],
#  [['Aberdeen', 'MS'], '15895'],
#  [['Aberdeen', 'NC'], '2337'],
#  [['Aberdeen', 'NJ'], '19818'],
#  [['Aberdeen', 'OH'], '6584'],
#  [['Aberdeen', 'SD'], '12280'],
#  [['Aberdeen', 'WA'], '1546'],
#  [['Abernathy', 'TX'], '16107'],
#  [['Abie', 'NE'], '23123'],
#  [['Abilene', 'KS'], '13529'],
#  [['Abilene', 'TX'], '11806'],
#  [['Abingdon', 'IL'], '17636'],
#  [['Abingdon', 'MD'], '1093'],
#  [['Abingdon', 'VA'], '1375'],
#  [['Abington Township', 'PA'], '6796'],
#  [['Abington', 'MA'], '1971'],
#  [['Abington', 'PA'], '2074'],
#  [['Abita Springs', 'LA'], '14708'],
#  [['Abram-Perezville', 'TX'], '24552'],
#  [['Abrams', 'WI'], '18019'],
#  [['Absecon', 'NJ'], '3266'],
#  [['Acampo', 'CA'], '10594'],
#  [['Accident', 'MD'], '7417'],
#  [['Accokeek', 'MD'], '4021'],
#  [['Accomac', 'VA'], '18571'],
#  [['Accord', 'NY'], '9774'],
#  [['Achille', 'OK'], '23561'],
#  [['Ackley', 'IA'], '17819'],
#  [['Ackworth', 'IA'], '21065'],
#  [['Acme', 'WA'], '9702'],
#  [['Acres Green', 'CO'], '6949'],
#  [['Acton', 'CA'], '4931'],
#  [['Acton', 'MA'], '1436'],
#  [['Acton', 'ME'], '17810'],
#  [['Acushnet', 'MA'], '2816'],
#  [['Acworth', 'GA'], '11900'],
#  [['Acworth', 'NH'], '16776'],
#  [['Ada', 'MN'], '15731'],
#  [['Ada', 'OH'], '3256'],
#  [['Ada', 'OK'], '1309'],
#  [['Adair Village', 'OR'], '11273'],
#  [['Adair', 'IA'], '19676'],
#  [['Adair', 'IL'], '21080'],
#  [['Adair', 'OK'], '7496'],
#  [['Adairsville', 'GA'], '12816'],
#  [['Adairville', 'KY'], '18631'],
#  [['Adams Center', 'NY'], '8656'],
#  [['Adams Run', 'SC'], '7731'],
#  [['Adams Township', 'PA'], '15740'],
#  [['Adams', 'MN'], '19001'],
#  [['Adams', 'NE'], '18439'],
#  [['Adams', 'OR'], '19775'],
#  [['Adams', 'TN'], '9743'],
#  [['Adams', 'WI'], '6087'],
#  [['Adamsburg', 'PA'], '10637'],
#  [['Adamstown', 'MD'], '6010'],
#  [['Adamstown', 'PA'], '9117'],
#  [['Adamsville', 'AL'], '4414'],
#  [['Adamsville', 'OH'], '18653'],
#  [['Adamsville', 'PA'], '22997'],
#  [['Adamsville', 'TN'], '13280'],
#  [['Addieville', 'IL'], '20202'],
#  [['Addington', 'OK'], '23246'],
#  [['Addis', 'LA'], '16743'],
#  [['Addison Township', 'PA'], '18544'],
#  [['Addison', 'AL'], '7801'],
#  [['Addison', 'IL'], '12169'],
#  [['Addison', 'ME'], '19453'],
#  [['Addison', 'MI'], '15549'],
#  [['Addison', 'TX'], '3325'],
#  [['Addison', 'VT'], '7907'],
#  [['Addison', 'WI'], '5506'],
#  [['Addy', 'WA'], '16988'],
#  [['Addyston', 'OH'], '11510'],
#  [['Adel', 'GA'], '13948'],
#  [['Adel', 'IA'], '3661'],
#  [['Adelanto', 'CA'], '1095'],
#  [['Adeline', 'IL'], '23037'],
#  [['Adell', 'WI'], '11112'],
#  [['Adelphi', 'MD'], '3033'],
#  [['Adelphi', 'OH'], '11277'],
#  [['Adena', 'OH'], '22666'],
#  [['Adin', 'CA'], '10892'],
#  [['Adolphus', 'KY'], '18542'],
#  [['Adona', 'AR'], '21246'],
#  [['Adrian Township', 'MI'], '12400'],
#  [['Adrian', 'GA'], '22543'],
#  [['Adrian', 'MN'], '15742'],
#  [['Adrian', 'MO'], '16123'],
#  [['Adrian', 'OR'], '23156'],
#  [['Advance', 'NC'], '2758'],
#  [['Affton', 'MO'], '1637'],
#  [['Afton', 'IA'], '21645'],
#  [['Afton', 'MI'], '20223'],
#  [['Afton', 'MN'], '9023'],
#  [['Afton', 'OK'], '4647'],
#  [['Afton', 'VA'], '18217'],
#  [['Afton', 'WY'], '14187'],
#  [['Agate', 'CO'], '11017'],
#  [['Agawam', 'MA'], '1928'],
#  [['Agency', 'IA'], '23047'],
#  [['Agness', 'OR'], '20691'],
#  [['Agoura Hills', 'CA'], '1490'],
#  [['Agra', 'OK'], '7876'],
#  [['Agua Dulce', 'TX'], '24669'],
#  [['Aguanga', 'CA'], '9196'],
#  [['Aguila', 'AZ'], '8825'],
#  [['Aguilar', 'CO'], '19362'],
#  [['Ahmeek', 'MI'], '22888'],
#  [['Ahoskie', 'NC'], '3015'],
#  [['Ahwahnee', 'CA'], '6809'],
#  [['Aiea', 'HI'], '763'],
#  [['Aiken', 'SC'], '433'],
#  [['Ailey', 'GA'], '21668'],
#  [['Ainsworth', 'IA'], '18938'],
#  [['Ainsworth', 'NE'], '19762'],
#  [['Airport Drive', 'MO'], '24166'],
#  [['Airville', 'PA'], '6316'],
#  [['Airway Heights', 'WA'], '10236'],
#  [['Aitkin', 'MN'], '15829'],
#  [['Ajo', 'AZ'], '6332'],
#  [['Akeley', 'MN'], '18942'],
#  [['Akron', 'CO'], '15376'],
#  [['Akron', 'IA'], '6659'],
#  [['Akron', 'IN'], '16309'],
#  [['Akron', 'MI'], '17225'],
#  [['Akron', 'NY'], '7869'],
#  [['Akron', 'OH'], '95'],
#  [['Akron', 'PA'], '6328'],
#  [['Alabama', 'NY'], '6787'],
#  [['Alabaster', 'AL'], '1269'],
#  [['Alachua', 'FL'], '12863'],
#  [['Alamance', 'NC'], '21395'],
#  [['Alameda', 'CA'], '417'],
#  [['Alamo Heights', 'TX'], '13482'],
#  [['Alamo', 'CA'], '1889'],
#  [['Alamo', 'GA'], '18072'],
#  [['Alamo', 'NV'], '10367'],
#  [['Alamo', 'TN'], '24011'],
#  [['Alamo', 'TX'], '13589'],
#  [['Alamogordo', 'NM'], '12172'],
#  [['Alamosa', 'CO'], '2148'],
#  [['Alanson', 'MI'], '14831'],
#  [['Alapaha', 'GA'], '19870'],
#  [['Alba', 'MI'], '23247'],
#  [['Alba', 'PA'], '22414'],
#  [['Alba', 'TX'], '24319'],
#  [['Albany Township', 'PA'], '7684'],
#  [['Albany', 'CA'], '1681'],
#  [['Albany', 'GA'], '11858'],
#  [['Albany', 'IL'], '18714'],
#  [['Albany', 'IN'], '16086'],
#  [['Albany', 'KY'], '14740'],
#  [['Albany', 'LA'], '17331'],
#  [['Albany', 'ME'], '24204'],
#  [['Albany', 'MN'], '6831'],
#  [['Albany', 'NH'], '15433'],
#  [['Albany', 'NY'], '226'],
#  [['Albany', 'OH'], '5780'],
#  [['Albany', 'OR'], '527'],
#  [['Albany', 'TX'], '24596'],
#  [['Albany', 'WI'], '18564'],
#  [['Albemarle', 'NC'], '1390'],
#  [['Albers', 'IL'], '22300'],
#  [['Albert City', 'IA'], '18649'],
#  [['Albert Lea', 'MN'], '12785'],
#  [['Alberta', 'AL'], '20477'],
#  [['Alberta', 'MN'], '20976'],
#  [['Alberta', 'VA'], '18586'],
#  [['Albertson', 'NC'], '11158'],
#  [['Albertson', 'NY'], '5946'],
#  [['Albertville', 'AL'], '1170'],
#  [['Albertville', 'MN'], '3677'],
#  [['Albia', 'IA'], '17495'],
#  [['Albin', 'WY'], '24151'],
#  [['Albion', 'CA'], '9515'],
#  [['Albion', 'IA'], '21801'],
#  [['Albion', 'IL'], '17691'],
#  [['Albion', 'IN'], '16031'],
#  [['Albion', 'ME'], '18251'],
#  [['Albion', 'MI'], '14652'],
#  [['Albion', 'NE'], '17793'],
#  [['Albion', 'NY'], '6855'],
#  [['Albion', 'PA'], '7790'],
#  [['Albion', 'WI'], '7044'],
#  [['Alborn', 'MN'], '10255'],
#  [['Albright', 'WV'], '19085'],
#  [['Albuquerque', 'NM'], '11737'],
#  [['Alburgh', 'VT'], '7413'],
#  [['Alburnett', 'IA'], '22175'],
#  [['Alburtis', 'PA'], '6685'],
#  [['Alcoa', 'TN'], '3856'],
#  [['Alcolu', 'SC'], '10722'],
#  [['Alda', 'NE'], '21095'],
#  [['Aldan', 'PA'], '5055'],
#  [['Alden', 'IA'], '16451'],
#  [['Alden', 'MI'], '23755'],
#  [['Alden', 'MN'], '22588'],
#  [['Alderpoint', 'CA'], '21718'],
#  [['Alderson', 'OK'], '11131'],
#  [['Alderson', 'WV'], '18717'],
#  [['Aldie', 'VA'], '3041'],
#  [['Aldine', 'TX'], '14642'],
#  [['Aldrich', 'MN'], '21449'],
#  [['Aledo', 'IL'], '15827'],
#  [['Aledo', 'TX'], '8674'],
#  [['Aleppo Township', 'PA'], '7633'],
#  [['Alex', 'OK'], '9912'],
#  [['Alexander City', 'AL'], '12614'],
#  [['Alexander', 'AR'], '10059'],
#  [['Alexander', 'IA'], '20639'],
#  [['Alexander', 'IL'], '19645'],
#  [['Alexander', 'ME'], '21046'],
#  [['Alexander', 'NC'], '8158'],
#  [['Alexandria Bay', 'NY'], '10813'],
#  [['Alexandria Township', 'NJ'], '4594'],
#  [['Alexandria', 'AL'], '7116'],
#  [['Alexandria', 'IN'], '13761'],
#  [['Alexandria', 'KY'], '2209'],
#  [['Alexandria', 'LA'], '12007'],
#  [['Alexandria', 'MN'], '3220'],
#  [['Alexandria', 'NE'], '21063'],
#  [['Alexandria', 'NH'], '16403'],
#  [['Alexandria', 'NY'], '7712'],
#  [['Alexandria', 'OH'], '6490'],
#  [['Alexandria', 'PA'], '11285'],
#  [['Alexandria', 'TN'], '16633'],
#  [['Alexandria', 'VA'], '129'],
#  [['Alexis', 'IL'], '20163'],
#  [['Alexis', 'NC'], '9954'],
#  [['Alford', 'FL'], '16604'],
#  [['Alford', 'MA'], '9832'],
#  [['Alfred', 'ME'], '17679'],
#  [['Alger', 'MI'], '15771'],
#  [['Alger', 'OH'], '8855'],
#  [['Alger', 'WA'], '10700'],
#  [['Algoma', 'WI'], '3411'],
#  [['Algona', 'IA'], '15613'],
#  [['Algona', 'WA'], '6393'],
#  [['Algonac', 'MI'], '12962'],
#  [['Algonquin', 'IL'], '12413'],
#  [['Algood', 'TN'], '16724'],
#  [['Alhambra', 'CA'], '293'],
#  [['Alhambra', 'IL'], '17168'],
#  [['Alice', 'TX'], '13595'],
#  [['Aliceville', 'AL'], '16985'],
#  [['Alicia', 'AR'], '22863'],
#  [['Aline', 'OK'], '20309'],
#  [['Aliquippa', 'PA'], '3073'],
#  [['Aliso Viejo', 'CA'], '661'],
#  [['Allamuchy Township', 'NJ'], '23930'],
#  [['Allamuchy-Panther Valley', 'NJ'], '6103'],
#  [['Allardt', 'TN'], '17432'],
#  [['Alledonia', 'OH'], '21229'],
#  [['Allegan', 'MI'], '12776'],
#  [['Allegany Township', 'PA'], '19510'],
#  [['Allegany', 'OR'], '23428'],
#  [['Alleghany', 'CA'], '10818'],
#  [['Allegheny Township', 'PA'], '3192'],
#  [['Alleman', 'IA'], '10441'],
#  [['Allen Park', 'MI'], '12311'],
#  [['Allen Township', 'PA'], '4895'],
#  [['Allen', 'KY'], '20248'],
#  [['Allen', 'MD'], '23456'],
#  [['Allen', 'MI'], '18887'],
#  [['Allen', 'NE'], '23359'],
#  [['Allen', 'NY'], '8882'],
#  [['Allen', 'OK'], '8183'],
#  [['Allen', 'TX'], '262'],
#  [['Allendale Township', 'MI'], '12523'],
#  [['Allendale', 'IL'], '19425'],
#  [['Allendale', 'NJ'], '4238'],
#  [['Allendale', 'SC'], '17631'],
#  [['Allenhurst', 'GA'], '15944'],
#  [['Allenhurst', 'NJ'], '9830'],
#  [['Allenspark', 'CO'], '10988'],
#  [['Allenstown', 'NH'], '16336'],
#  [['Allensville', 'KY'], '19681'],
#  [['Allenton', 'MI'], '16104'],
#  [['Allentown', 'GA'], '22172'],
#  [['Allentown', 'NJ'], '7363'],
#  [['Allentown', 'PA'], '164'],
#  [['Allenwood', 'NJ'], '8962'],
#  [['Allerton', 'IA'], '19487'],
#  [['Allerton', 'IL'], '21660'],
#  [['Allgood', 'AL'], '22682'],
#  [['Alliance', 'NC'], '21566'],
#  [['Alliance', 'NE'], '15065'],
#  [['Alliance', 'OH'], '930'],
#  [['Allison Township', 'PA'], '19693'],
#  [['Allison', 'IA'], '18980'],
#  [['Allons', 'TN'], '17056'],
#  [['Allouez', 'MI'], '20974'],
#  [['Allouez', 'WI'], '2211'],
#  [['Alloway Township', 'NJ'], '10345'],
#  [['Allport', 'AR'], '23756'],
#  [['Allyn', 'WA'], '7449'],
#  [['Alma Center', 'WI'], '23757'],
#  [['Alma', 'AR'], '6099'],
#  [['Alma', 'CO'], '11423'],
#  [['Alma', 'GA'], '17493'],
#  [['Alma', 'IL'], '19636'],
#  [['Alma', 'MI'], '14662'],
#  [['Alma', 'NE'], '23030'],
#  [['Alma', 'NY'], '8718'],
#  [['Alma', 'TX'], '10171'],
#  [['Alma', 'WI'], '18370'],
#  [['Almedia', 'PA'], '9421'],
#  [['Almena', 'WI'], '18882'],
#  [['Almira', 'WA'], '20807'],
#  [['Almo', 'KY'], '23758'],
#  [['Almond', 'WI'], '18029'],
#  [['Almont', 'CO'], '21193'],
#  [['Almont', 'MI'], '14764'],
#  [['Almyra', 'AR'], '18864'],
#  [['Alna', 'ME'], '19672'],
#  [['Aloha', 'OR'], '568'],
#  [['Alondra Park', 'CA'], '3492'],
#  [['Alorton', 'IL'], '16612'],
#  [['Alpaugh', 'CA'], '8562'],
#  [['Alpena', 'AR'], '18147'],
#  [['Alpena', 'MI'], '12533'],
#  [['Alpha', 'IL'], '22423'],
#  [['Alpha', 'KY'], '20724'],
#  [['Alpha', 'MI'], '23248'],
#  [['Alpha', 'MN'], '22022'],
#  [['Alpha', 'NJ'], '6565'],
#  [['Alpharetta', 'GA'], '12115'],
#  [['Alpine Township', 'MI'], '17076'],
#  [['Alpine', 'AZ'], '22577'],
#  [['Alpine', 'CA'], '2492'],
#  [['Alpine', 'NJ'], '8996'],
#  [['Alpine', 'TX'], '13875'],
#  [['Alpine', 'UT'], '13873'],
#  [['Alpine', 'WY'], '14506'],
#  [['Alsace Township', 'PA'], '5259'],
#  [['Alsea', 'OR'], '9322'],
#  [['Alsip', 'IL'], '12564'],
#  [['Alstead', 'NH'], '16334'],
#  [['Alston', 'GA'], '21894'],
#  [['Alta Vista', 'IA'], '19242'],
#  [['Alta', 'CA'], '10364'],
#  [['Alta', 'IA'], '15366'],
#  [['Altadena', 'CA'], '860'],
#  [['Altamahaw', 'NC'], '20527'],
#  [['Altamont', 'IL'], '17080'],
#  [['Altamont', 'KS'], '18195'],
#  [['Altamont', 'PA'], '20292'],
#  [['Altamonte Springs', 'FL'], '12020'],
#  [['Altavista', 'VA'], '6947'],
#  [['Altha', 'FL'], '17514'],
#  [['Altheimer', 'AR'], '22645'],
#  [['Altmar', 'NY'], '21977'],
#  [['Alto Pass', 'IL'], '21945'],
#  [['Alto', 'GA'], '15120'],
#  [['Alto', 'NM'], '13363'],
#  [['Alton North', 'TX'], '24557'],
#  [['Alton', 'IA'], '18024'],
#  [['Alton', 'IL'], '12532'],
#  [['Alton', 'ME'], '19591'],
#  [['Alton', 'NH'], '13304'],
#  [['Alton', 'TX'], '24518'],
#  [['Alton', 'VA'], '8131'],
#  [['Altona', 'IL'], '19792'],
#  [['Altoona', 'AL'], '21039'],
#  [['Altoona', 'FL'], '16414'],
#  [['Altoona', 'IA'], '2331'],
#  [['Altoona', 'PA'], '677'],
#  [['Altoona', 'WI'], '4234'],
#  [['Altura', 'MN'], '22397'],
#  [['Alturas', 'CA'], '5538'],
#  [['Altus', 'AR'], '21786'],
#  [['Altus', 'OK'], '2608'],
#  [['Alum Bridge', 'WV'], '20282'],
#  [['Alum Creek', 'WV'], '17684'],
#  [['Alum Rock', 'CA'], '2218'],
#  [['Alva', 'FL'], '14185'],
#  [['Alva', 'OK'], '14309'],
#  [['Alvada', 'OH'], '23759'],
#  [['Alvarado', 'MN'], '21862'],
#  [['Alvarado', 'TX'], '8633'],
#  [['Alvaton', 'KY'], '14335'],
#  [['Alvin', 'IL'], '21078'],
#  [['Alvin', 'TX'], '12480'],
#  [['Alvo', 'NE'], '20336'],
#  [['Alvord', 'IA'], '20358'],
#  [['Alvord', 'TX'], '17115'],
#  [['Alvordton', 'OH'], '8339'],
#  [['Ama', 'LA'], '18607'],
#  [['Amado', 'AZ'], '6222'],
#  [['Amador City', 'CA'], '11247'],
#  [['Amagansett', 'NY'], '9748'],
#  [['Amagon', 'AR'], '22064'],
#  [['Amana', 'IA'], '20501'],
#  [['Amanda Park', 'WA'], '10212'],
#  [['Amanda', 'OH'], '4650'],
#  [['Amargosa Valley', 'NV'], '9533'],
#  [['Amarillo', 'TX'], '11772'],
#  [['Amber', 'OK'], '9963'],
#  [['Amberg', 'WI'], '10592'],
#  [['Amberley', 'OH'], '5296'],
#  [['Ambler', 'PA'], '3979'],
#  [['Amboy', 'CA'], '22986'],
#  [['Amboy', 'IL'], '17833'],
#  [['Amboy', 'IN'], '16580'],
#  [['Amboy', 'MN'], '10058'],
#  [['Amboy', 'NY'], '8283'],
#  [['Amboy', 'WA'], '11141'],
#  [['Ambridge', 'PA'], '3711'],
#  [['Ambrose', 'GA'], '16178'],
#  [['Amelia Court House', 'VA'], '13925'],
#  [['Amelia', 'OH'], '2321'],
#  [['Amenia', 'ND'], '24297'],
#  [['American Canyon', 'CA'], '1707'],
#  [['American Falls', 'ID'], '24687'],
#  [['American Fork', 'UT'], '13657'],
#  [['Americus', 'GA'], '12420'],
#  [['Amery', 'WI'], '3322'],
#  [['Ames', 'IA'], '437'],
#  [['Ames', 'NE'], '21138'],
#  [['Ames', 'NY'], '23660'],
#  [['Ames', 'OK'], '18985'],
#  [['Amesville', 'OH'], '11560'],
#  [['Amherst Junction', 'WI'], '17964'],
#  [['Amherst', 'CO'], '21172'],
#  [['Amherst', 'MA'], '802'],
#  [['Amherst', 'ME'], '21600'],
#  [['Amherst', 'NE'], '20203'],
#  [['Amherst', 'NH'], '12898'],
#  [['Amherst', 'NY'], '165'],
#  [['Amherst', 'OH'], '3363'],
#  [['Amherst', 'VA'], '3562'],
#  [['Amherst', 'WI'], '18122'],
#  [['Amherstdale', 'WV'], '17536'],
#  [['Amissville', 'VA'], '4526'],
#  [['Amite', 'LA'], '17291'],
#  [['Amity Gardens', 'PA'], '5653'],
#  [['Amity Township', 'PA'], '3066'],
#  [['Amity', 'AR'], '7444'],
#  [['Amity', 'ME'], '21501'],
#  [['Amity', 'NY'], '7763'],
#  [['Amity', 'OR'], '8258'],
#  [['Amityville', 'NY'], '1314'],
#  [['Ammon', 'ID'], '13316'],
#  [['Amorita', 'OK'], '21874'],
#  [['Amory', 'MS'], '13977'],
#  [['Amsterdam', 'OH'], '7680'],
#  [['Amwell Township', 'PA'], '5292'],
#  [['Anacoco', 'LA'], '17326'],
#  [['Anaconda', 'MT'], '13474'],
#  [['Anacortes', 'WA'], '1814'],
#  [['Anadarko', 'OK'], '3312'],
#  [['Anaheim', 'CA'], '38'],
#  [['Anahuac', 'TX'], '14169'],
#  [['Anamosa', 'IA'], '14071'],
#  [['Anatone', 'WA'], '18790'],
#  [['Anchor Point', 'AK'], '14491'],
#  [['Anchor', 'IL'], '23157'],
#  [['Anchorage', 'AK'], '11747'],
#  [['Anchorage', 'KY'], '15463'],
#  [['Ancient Oaks', 'PA'], '4693'],
#  [['Ancona', 'IL'], '21505'],
#  [['Ancram', 'NY'], '7800'],
#  [['Andale', 'KS'], '16663'],
#  [['Andalusia', 'AL'], '5238'],
#  [['Andalusia', 'IL'], '17263'],
#  [['Anderson Mill', 'TX'], '15580'],
#  [['Anderson', 'AL'], '16762'],
#  [['Anderson', 'CA'], '1996'],
#  [['Anderson', 'IN'], '12062'],
#  [['Anderson', 'SC'], '258'],
#  [['Andersonville', 'GA'], '19483'],
#  [['Andersonville', 'TN'], '7311'],
#  [['Andover Township', 'NJ'], '3574'],
#  [['Andover', 'CT'], '5869'],
#  [['Andover', 'IA'], '23158'],
#  [['Andover', 'IL'], '22358'],
#  [['Andover', 'KS'], '12802'],
#  [['Andover', 'ME'], '24153'],
#  [['Andover', 'MN'], '999'],
#  [['Andover', 'NH'], '16240'],
#  [['Andover', 'OH'], '5071'],
#  [['Andover', 'VT'], '9874'],
#  [['Andrew', 'IA'], '23360'],
#  [['Andrews AFB', 'MD'], '17595'],
#  [['Andrews', 'FL'], '22000'],
#  [['Andrews', 'IN'], '16772'],
#  [['Andrews', 'NC'], '5234'],
#  [['Andrews', 'SC'], '3968'],
#  [['Andrews', 'TX'], '13730'],
#  [['Angel Fire', 'NM'], '13389'],
#  [['Angels', 'CA'], '11726'],
#  [['Angelus Oaks', 'CA'], '10976'],
#  [['Angier', 'NC'], '2638'],
#  [['Angle Inlet', 'MN'], '22718'],
#  [['Angleton', 'TX'], '12728'],
#  [['Angola on the Lake', 'NY'], '8407'],
#  [['Angola', 'IN'], '12722'],
#  [['Angola', 'NY'], '7252'],
#  [['Angora', 'MN'], '10599'],
#  [['Angora', 'NE'], '23361'],
#  [['Angus', 'MN'], '21274'],
#  [['Angwin', 'CA'], '17628'],
#  [['Anita', 'IA'], '18913'],
#  [['Aniwa', 'WI'], '10992'],
#  [['Ankeny', 'IA'], '784'],
#  [['Anmoore', 'WV'], '21670'],
#  [['Ann Arbor', 'MI'], '11831'],
#  [['Anna Maria', 'FL'], '14524'],
#  [['Anna', 'IL'], '14749'],
#  [['Anna', 'OH'], '5567'],
#  [['Anna', 'TX'], '2795'],
#  [['Annandale', 'MN'], '4091'],
#  [['Annandale', 'VA'], '498'],
#  [['Annapolis Junction', 'MD'], '18116'],
#  [['Annapolis', 'CA'], '10951'],
#  [['Annapolis', 'IL'], '22624'],
#  [['Annapolis', 'MD'], '243'],
#  [['Annawan', 'IL'], '16641'],
#  [['Annetta North', 'TX'], '8611'],
#  [['Annetta South', 'TX'], '9779'],
#  [['Annetta', 'TX'], '9143'],
#  [['Annin Township', 'PA'], '19079'],
#  [['Anniston', 'AL'], '1819'],
#  [['Annsville', 'NY'], '5962'],
#  [['Annville', 'KY'], '18048'],
#  [['Annville', 'PA'], '4737'],
#  [['Anoka', 'MN'], '1941'],
#  [['Anselmo', 'NE'], '20717'],
#  [['Ansley', 'NE'], '23159'],
#  [['Anson', 'TX'], '24450'],
#  [['Ansonia', 'CT'], '1652'],
#  [['Ansonia', 'OH'], '8273'],
#  [['Ansonville', 'NC'], '11118'],
#  [['Ansted', 'WV'], '19567'],
#  [['Anthem', 'AZ'], '871'],
#  [['Anthon', 'IA'], '19595'],
#  [['Anthony Township', 'PA'], '9025'],
#  [['Anthony', 'FL'], '16343'],
#  [['Anthony', 'KS'], '24574'],
#  [['Anthony', 'NM'], '13734'],
#  [['Anthony', 'PA'], '18305'],
#  [['Anthony', 'TX'], '24430'],
#  [['Anthonyville', 'AR'], '23858'],
#  [['Antigo', 'WI'], '2577'],
#  [['Antioch', 'CA'], '238'],
#  [['Antioch', 'IL'], '12509'],
#  [['Antis', 'PA'], '17071'],
#  [['Antlers', 'OK'], '5874'],
#  [['Antoine', 'AR'], '23760'],
#  [['Anton', 'TX'], '16409'],
#  [['Antonito', 'CO'], '14282'],
#  [['Antrim Township', 'PA'], '2049'],
#  [['Antwerp', 'OH'], '5757'],
#  [['Anza', 'CA'], '6350'],
#  [['Apache Junction', 'AZ'], '667'],
#  [['Apache', 'OK'], '15219'],
#  [['Apalachicola', 'FL'], '14381'],
#  [['Apalachin', 'NY'], '15439'],
#  [['Apex', 'NC'], '651'],
#  [['Aplington', 'IA'], '19113'],
#  [['Apolacon Township', 'PA'], '19467'],
#  [['Apollo Beach', 'FL'], '12958'],
#  [['Apollo', 'PA'], '7603'],
#  [['Apopka', 'FL'], '11893'],
#  [['Appalachia', 'VA'], '5964'],
#  [['Apple Creek', 'OH'], '3865'],
#  [['Apple Grove', 'WV'], '19328'],
#  [['Apple River', 'IL'], '14930'],
#  [['Apple Valley', 'CA'], '374'],
#  [['Apple Valley', 'MN'], '597'],
#  [['Applegate', 'CA'], '9315'],
#  [['Appleton', 'ME'], '18317'],
#  [['Appleton', 'MN'], '19372'],
#  [['Appleton', 'WA'], '23457'],
#  [['Appleton', 'WI'], '429'],
#  [['Applewold', 'PA'], '22605'],
#  [['Applewood', 'CO'], '4783'],
#  [['Appling', 'GA'], '14001'],
#  [['Appomattox', 'VA'], '14604'],
#  [['Aptos', 'CA'], '1326'],
#  [['Aquilla', 'OH'], '11103'],
#  [['Aquilla', 'TX'], '24412'],
#  [['Aquinnah', 'MA'], '10026'],
#  [['Arab', 'AL'], '2417'],
#  [['Arabi', 'GA'], '19381'],
#  [['Arabi', 'LA'], '17083'],
#  [['Aragon', 'GA'], '16182'],
#  [['Aransas Pass', 'TX'], '13021'],
#  [['Arapaho', 'OK'], '16859'],
#  [['Arapahoe', 'CO'], '23362'],
#  [['Arapahoe', 'NC'], '21989'],
#  [['Arapahoe', 'NE'], '18712'],
#  [['Ararat Township', 'PA'], '19929'],
#  [['Ararat', 'NC'], '18735'],
#  [['Ararat', 'VA'], '6650'],
#  [['Arbuckle', 'CA'], '5539'],
#  [['Arcade', 'GA'], '22407'],
#  [['Arcade', 'NY'], '8751'],
#  [['Arcadia', 'CA'], '446'],
#  [['Arcadia', 'FL'], '12186'],
#  [['Arcadia', 'IA'], '19444'],
#  [['Arcadia', 'IN'], '7585'],
#  [['Arcadia', 'LA'], '17327'],
#  [['Arcadia', 'MI'], '20795'],
#  [['Arcadia', 'NE'], '20293'],
#  [['Arcadia', 'NY'], '3716'],
#  [['Arcadia', 'OH'], '10800'],
#  [['Arcadia', 'OK'], '10783'],
#  [['Arcadia', 'WI'], '6588'],
#  [['Arcanum', 'OH'], '10312'],
#  [['Arcata', 'CA'], '1717'],
#  [['Arch Cape', 'OR'], '9631'],
#  [['Archbald', 'PA'], '3697'],
#  [['Archbold', 'OH'], '3650'],
#  [['Archdale', 'NC'], '13521'],
#  [['Archer', 'FL'], '14167'],
#  [['Archer', 'IA'], '21267'],
#  [['Archer', 'NE'], '22299'],
#  [['Archie', 'MO'], '16577'],
#  [['Arco', 'MN'], '21552'],
#  [['Arcola', 'IL'], '17498'],
#  [['Arcola', 'TX'], '17359'],
#  [['Arden Hills', 'MN'], '2962'],
#  [['Arden', 'DE'], '19930'],
#  [['Arden', 'NC'], '1585'],
#  [['Arden-Arcade', 'CA'], '302'],
#  [['Ardencroft', 'DE'], '10408'],
#  [['Ardentown', 'DE'], '20577'],
#  [['Ardmore', 'AL'], '4499'],
#  [['Ardmore', 'OK'], '1514'],
#  [['Ardmore', 'PA'], '2390'],
#  [['Ardmore', 'TN'], '15350'],
#  [['Ardsley', 'NY'], '4855'],
#  [['Aredale', 'IA'], '23761'],
#  [['Arena', 'WI'], '11334'],
#  [['Arenzville', 'IL'], '20451'],
#  [['Argenta', 'IL'], '17736'],
#  [['Argentine', 'MI'], '17125'],
#  [['Argillite', 'KY'], '9192'],
#  [['Argo', 'AL'], '8913'],
#  [['Argonne', 'WI'], '14938'],
#  [['Argos', 'IN'], '5981'],
#  [['Argusville', 'ND'], '24090'],
#  [['Argyle', 'GA'], '22858'],
#  [['Argyle', 'IA'], '19865'],
#  [['Argyle', 'MN'], '20965'],
#  [['Argyle', 'TX'], '5704'],
#  [['Argyle', 'WI'], '21040'],
#  [['Ariel', 'WA'], '10808'],
#  [['Arietta', 'NY'], '21851'],
#  [['Arion', 'IA'], '21831'],
#  [['Aristes', 'PA'], '23249'],
#  [['Ariton', 'AL'], '6961'],
#  [['Arivaca', 'AZ'], '10541'],
#  [['Arkadelphia', 'AR'], '3532'],
#  [['Arkansas City', 'AR'], '20979'],
#  [['Arkansaw', 'WI'], '18684'],
#  [['Arkdale', 'WI'], '8648'],
#  [['Arkoma', 'OK'], '8607'],
#  [['Arkport', 'NY'], '10830'],
#  [['Arkwright', 'NY'], '18992'],
#  [['Arlee', 'MT'], '24582'],
#  [['Arley', 'AL'], '6628'],
#  [['Arlington Heights', 'IL'], '11917'],
#  [['Arlington Heights', 'OH'], '9206'],
#  [['Arlington Heights', 'PA'], '4073'],
#  [['Arlington', 'AL'], '21591'],
#  [['Arlington', 'AZ'], '9758'],
#  [['Arlington', 'GA'], '17979'],
#  [['Arlington', 'IA'], '19188'],
#  [['Arlington', 'IL'], '18330'],
#  [['Arlington', 'KS'], '19486'],
#  [['Arlington', 'KY'], '18522'],
#  [['Arlington', 'MA'], '705'],
#  [['Arlington', 'MN'], '17614'],
#  [['Arlington', 'NE'], '7278'],
#  [['Arlington', 'OH'], '6405'],
#  [['Arlington', 'OR'], '19207'],
#  [['Arlington', 'TN'], '2513'],
#  [['Arlington', 'TX'], '36'],
#  [['Arlington', 'VA'], '74'],
#  [['Arlington', 'WA'], '954'],
#  [['Arlington', 'WI'], '11046'],
#  [['Arma', 'KS'], '24600'],
#  [['Armada', 'MI'], '15149'],
#  [['Armagh Township', 'PA'], '6108'],
#  [['Armagh', 'PA'], '23562'],
#  [['Armenia Township', 'PA'], '9576'],
#  [['Armington', 'IL'], '19820'],
#  [['Armona', 'CA'], '10304'],
#  [['Armonk', 'NY'], '15746'],
#  [['Armour', 'SD'], '24044'],
#  [['Armstrong Creek', 'WI'], '20512'],
#  [['Armstrong Township', 'PA'], '10895'],
#  [['Armstrong', 'IA'], '18297'],
#  [['Armstrong', 'IL'], '20008'],
#  [['Armstrong', 'MO'], '24173'],
#  [['Armstrong', 'OK'], '23908'],
#  [['Armuchee', 'GA'], '17042'],
#  [['Arnett', 'OK'], '19272'],
#  [['Arnold', 'CA'], '8225'],
#  [['Arnold', 'MD'], '1580'],
#  [['Arnold', 'MN'], '7616'],
#  [['Arnold', 'MO'], '896'],
#  [['Arnold', 'NE'], '20538'],
#  [['Arnold', 'PA'], '4564'],
#  [['Arnolds Park', 'IA'], '15520'],
#  [['Arnoldsville', 'GA'], '16833'],
#  [['Aroda', 'VA'], '18636'],
#  [['Aroma Park', 'IL'], '22944'],
#  [['Aromas', 'CA'], '5889'],
#  [['Arona', 'PA'], '10758'],
#  [['Arpin', 'WI'], '6475'],
#  [['Arriba', 'CO'], '21509'],
#  [['Arrington', 'TN'], '9652'],
#  [['Arrington', 'VA'], '22056'],
#  [['Arrowsic', 'ME'], '20503'],
#  [['Arrowsmith', 'IL'], '23120'],
#  [['Arroyo Grande', 'CA'], '1176'],
#  [['Artesia', 'CA'], '1906'],
#  [['Artesia', 'NM'], '23941'],
#  [['Arthur', 'IA'], '20882'],
#  [['Arthur', 'IL'], '17680'],
#  [['Arthur', 'ND'], '24245'],
#  [['Arthur', 'NE'], '20828'],
#  [['Arundel', 'ME'], '5109'],
#  [['Arvada', 'CO'], '241'],
#  [['Arvin', 'CA'], '1654'],
#  [['Arvonia', 'VA'], '20909'],
#  [['Asbury Lake', 'FL'], '16391'],
#  [['Asbury Park', 'NJ'], '1962'],
#  [['Asbury', 'IA'], '8474'],
#  [['Ash Flat', 'AR'], '21100'],
#  [['Ash Fork', 'AZ'], '8461'],
#  [['Ash Grove', 'MO'], '16281'],
#  [['Ash', 'NC'], '4000'],
#  [['Asharoken', 'NY'], '19717'],
#  [['Ashaway', 'RI'], '10363'],
#  [['Ashburn', 'GA'], '17475'],
#  [['Ashburn', 'VA'], '305'],
#  [['Ashburnham', 'MA'], '5079'],
#  [['Ashby', 'MA'], '5822'],
#  [['Ashby', 'MN'], '20458'],
#  [['Ashby', 'NE'], '21382'],
#  [['Ashcamp', 'KY'], '20141'],
#  [['Ashdown', 'AR'], '15423'],
#  [['Asheboro', 'NC'], '12105'],
#  [['Asher', 'OK'], '9189'],
#  [['Asherton', 'TX'], '24626'],
#  [['Asheville', 'NC'], '368'],
#  [['Ashfield', 'MA'], '7501'],
#  [['Ashford', 'AL'], '9081'],
#  [['Ashford', 'CT'], '4964'],
#  [['Ashford', 'NY'], '7277'],
#  [['Ashford', 'WA'], '8879'],
#  [['Ashkum', 'IL'], '19598'],
#  [['Ashland City', 'TN'], '6101'],
#  [['Ashland Township', 'PA'], '18773'],
#  [['Ashland', 'AL'], '17664'],
#  [['Ashland', 'IL'], '8083'],
#  [['Ashland', 'KY'], '12563'],
#  [['Ashland', 'MA'], '1883'],
#  [['Ashland', 'MO'], '14386'],
#  [['Ashland', 'NE'], '6020'],
#  [['Ashland', 'NH'], '15762'],
#  [['Ashland', 'NY'], '9167'],
#  [['Ashland', 'OH'], '12823'],
#  [['Ashland', 'OR'], '1317'],
#  [['Ashland', 'PA'], '6136'],
#  [['Ashland', 'VA'], '2077'],
#  [['Ashland', 'WI'], '2716'],
#  [['Ashley', 'IL'], '18507'],
#  [['Ashley', 'MI'], '18462'],
#  [['Ashley', 'OH'], '5683'],
#  [['Ashley', 'PA'], '6255'],
#  [['Ashmore', 'IL'], '17235'],
#  [['Ashtabula', 'OH'], '2216'],
#  [['Ashton', 'IA'], '19639'],
#  [['Ashton', 'IL'], '20032'],
#  [['Ashton', 'MD'], '8915'],
#  [['Ashton', 'NE'], '21198'],
#  [['Ashton', 'WV'], '20007'],
#  [['Ashville', 'AL'], '5365'],
#  [['Ashville', 'OH'], '4127'],
#  [['Ashville', 'PA'], '23363'],
#  [['Ashwaubenon', 'WI'], '1978'],
#  [['Askewville', 'NC'], '22792'],
#  [['Askov', 'MN'], '11219'],
#  [['Asotin', 'WA'], '19144'],
#  [['Aspen', 'CO'], '2828'],
#  [['Aspers', 'PA'], '21931'],
#  [['Aspinwall', 'PA'], '6273'],
#  [['Assaria', 'KS'], '23563'],
#  [['Assumption', 'IL'], '18271'],
#  [['Astatula', 'FL'], '16296'],
#  [['Aston', 'PA'], '2793'],
#  [['Astor', 'FL'], '15386'],
#  [['Astoria', 'IL'], '18068'],
#  [['Astoria', 'OR'], '1986'],
#  [['Asylum', 'PA'], '18839'],
#  [['Atalissa', 'IA'], '18880'],
#  [['Atascadero', 'CA'], '1034'],
#  [['Atascocita', 'TX'], '12030'],
#  [['Atascosa', 'TX'], '15889'],
#  [['Atchison', 'KS'], '13685'],
#  [['Atglen', 'PA'], '8033'],
#  [['Athalia', 'OH'], '11143'],
#  [['Athelstane', 'WI'], '9157'],
#  [['Athena', 'OR'], '10340'],
#  [['Athens Township', 'PA'], '3214'],
#  [['Athens', 'AL'], '12183'],
#  [['Athens', 'GA'], '11828'],
#  [['Athens', 'IL'], '15704'],
#  [['Athens', 'MI'], '17245'],
#  [['Athens', 'OH'], '1007'],
#  [['Athens', 'TN'], '12588'],
#  [['Athens', 'TX'], '12641'],
#  [['Athens', 'VT'], '20080'],
#  [['Athens', 'WI'], '5422'],
#  [['Atherton', 'CA'], '3688'],
#  [['Athol', 'ID'], '13907'],
#  [['Atkins', 'AR'], '6299'],
#  [['Atkins', 'IA'], '23733'],
#  [['Atkins', 'VA'], '18996'],
#  [['Atkinson', 'IL'], '16683'],
#  [['Atkinson', 'NC'], '8134'],
#  [['Atkinson', 'NE'], '17971'],
#  [['Atkinson', 'NH'], '15304'],
#  [['Atlanta', 'GA'], '11739'],
#  [['Atlanta', 'IL'], '18453'],
#  [['Atlanta', 'IN'], '16222'],
#  [['Atlanta', 'MI'], '13296'],
#  [['Atlanta', 'NE'], '23762'],
#  [['Atlanta', 'TX'], '13839'],
#  [['Atlantic Beach', 'FL'], '13169'],
#  [['Atlantic Beach', 'NC'], '8476'],
#  [['Atlantic Beach', 'NY'], '8521'],
#  [['Atlantic Beach', 'SC'], '10491'],
#  [['Atlantic City', 'NJ'], '1185'],
#  [['Atlantic Highlands', 'NJ'], '5097'],
#  [['Atlantic Mine', 'MI'], '18550'],
#  [['Atlantic', 'IA'], '3360'],
#  [['Atlantic', 'NC'], '9984'],
#  [['Atlantic', 'VA'], '20569'],
#  [['Atlantis', 'FL'], '14347'],
#  [['Atmore', 'AL'], '1901'],
#  [['Atoka', 'OK'], '7506'],
#  [['Atoka', 'TN'], '2850'],
#  [['Attalla', 'AL'], '2898'],
#  [['Attapulgus', 'GA'], '18490'],
#  [['Attica', 'IN'], '16005'],
#  [['Attica', 'MI'], '15732'],
#  [['Attica', 'OH'], '6849'],
#  [['Attleboro', 'MA'], '697'],
#  [['Atwater', 'CA'], '972'],
#  [['Atwater', 'MN'], '17108'],
#  [['Atwater', 'OH'], '4419'],
#  [['Atwood', 'CO'], '9838'],
#  [['Atwood', 'IL'], '18873'],
#  [['Atwood', 'OK'], '21061'],
#  [['Atwood', 'PA'], '22025'],
#  [['Atwood', 'TN'], '16631'],
#  [['Au Gres', 'MI'], '13333'],
#  [['Au Sable Forks', 'NY'], '10355'],
#  [['Au Sable Township', 'MI'], '14919'],
#  [['Au Sable', 'NY'], '6198'],
#  [['Au Train', 'MI'], '19791'],
#  [['Auberry', 'CA'], '8553'],
#  [['Aubrey', 'AR'], '23048'],
#  [['Aubrey', 'TX'], '9443'],
#  [['Auburn Hills', 'MI'], '13612'],
#  [['Auburn Township', 'PA'], '18206'],
#  [['Auburn', 'AL'], '857'],
#  [['Auburn', 'CA'], '744'],
#  [['Auburn', 'GA'], '12899'],
#  [['Auburn', 'IA'], '23049'],
#  [['Auburn', 'IL'], '15723'],
#  [['Auburn', 'IN'], '12549'],
#  [['Auburn', 'KS'], '16568'],
#  [['Auburn', 'KY'], '17667'],
#  [['Auburn', 'MA'], '1943'],
#  [['Auburn', 'ME'], '1386'],
#  [['Auburn', 'MI'], '14757'],
#  [['Auburn', 'NE'], '15225'],
#  [['Auburn', 'NH'], '15169'],
#  [['Auburn', 'NY'], '1140'],
#  [['Auburn', 'PA'], '9409'],
#  [['Auburn', 'WA'], '423'],
#  [['Auburndale', 'FL'], '12357'],
#  [['Auburndale', 'WI'], '8500'],
#  [['Auburntown', 'TN'], '9688'],
#  [['Audubon Park', 'KY'], '16488'],
#  [['Audubon Park', 'NJ'], '18857'],
#  [['Audubon', 'IA'], '22276'],
#  [['Audubon', 'MN'], '7490'],
#  [['Audubon', 'NJ'], '3139'],
#  [['Audubon', 'PA'], '3467'],
#  [['August', 'CA'], '4342'],
#  [['Augusta Township', 'MI'], '15615'],
#  [['Augusta', 'AR'], '20426'],
#  [['Augusta', 'GA'], '11763'],
#  [['Augusta', 'KS'], '14640'],
#  [['Augusta', 'KY'], '17834'],
#  [['Augusta', 'ME'], '12548'],
#  [['Augusta', 'MI'], '16981'],
#  [['Augusta', 'MO'], '9136'],
#  [['Augusta', 'MT'], '24177'],
#  [['Augusta', 'NY'], '7288'],
#  [['Augusta', 'WI'], '4975'],
#  [['Augusta', 'WV'], '14249'],
#  [['Aulander', 'NC'], '17923'],
#  [['Ault', 'CO'], '9706'],
#  [['Aumsville', 'OR'], '7405'],
#  [['Aurelia', 'IA'], '18252'],
#  [['Aurelius', 'NY'], '7002'],
#  [['Aurora', 'CO'], '40'],
#  [['Aurora', 'IA'], '22209'],
#  [['Aurora', 'IL'], '11778'],
#  [['Aurora', 'IN'], '6043'],
#  [['Aurora', 'ME'], '21659'],
#  [['Aurora', 'MN'], '6404'],
#  [['Aurora', 'MO'], '12977'],
#  [['Aurora', 'NC'], '17725'],
#  [['Aurora', 'NE'], '8409'],
#  [['Aurora', 'NY'], '15562'],
#  [['Aurora', 'OH'], '2011'],
#  [['Aurora', 'OR'], '6298'],
#  [['Aurora', 'TX'], '20889'],
#  [['Aurora', 'WV'], '21121'],
#  [['Austell', 'GA'], '12174'],
#  [['Austerlitz', 'NY'], '7945'],
#  [['Austin', 'AR'], '4519'],
#  [['Austin', 'IN'], '15902'],
#  [['Austin', 'KY'], '23630'],
#  [['Austin', 'MN'], '1562'],
#  [['Austin', 'PA'], '22253'],
#  [['Austin', 'TX'], '11734'],
#  [['Austinburg', 'OH'], '10650'],
#  [['Austintown', 'OH'], '1338'],
#  [['Austinville', 'VA'], '8713'],
#  [['Autaugaville', 'AL'], '16617'],
#  [['Autryville', 'NC'], '8576'],
#  [['Auxier', 'KY'], '20000'],
#  [['Auxvasse', 'MO'], '24561'],
#  [['Ava', 'IL'], '17955'],
#  [['Ava', 'MO'], '13493'],
#  [['Ava', 'NY'], '9290'],
#  [['Avalon', 'CA'], '5579'],
#  [['Avalon', 'GA'], '21306'],
#  [['Avalon', 'NJ'], '8358'],
#  [['Avalon', 'PA'], '4720'],
#  [['Avenal', 'CA'], '2842'],
#  [['Avenel', 'NJ'], '15038'],
#  [['Aventura', 'FL'], '12214'],
#  [['Avenue', 'MD'], '10438'],
#  [['Avera', 'GA'], '19384'],
#  [['Averill Park', 'NY'], '4399'],
#  [['Avery', 'CA'], '10107'],
#  [['Avila Beach', 'CA'], '10846'],
#  [['Avilla', 'IN'], '15979'],
#  [['Avinger', 'TX'], '16830'],
#  [['Avis', 'PA'], '18096'],
#  [['Aviston', 'IL'], '18143'],
#  [['Avoca', 'IA'], '17152'],
#  [['Avoca', 'MI'], '16023'],
#  [['Avoca', 'MN'], '23735'],
#  [['Avoca', 'NE'], '20381'],
#  [['Avoca', 'PA'], '6676'],
#  [['Avoca', 'WI'], '10453'],
#  [['Avocado Heights', 'CA'], '2733'],
#  [['Avon Lake', 'OH'], '1583'],
#  [['Avon Park', 'FL'], '12443'],
#  [['Avon by the Sea', 'NJ'], '7509'],
#  [['Avon', 'AL'], '9835'],
#  [['Avon', 'CO'], '5295'],
#  [['Avon', 'CT'], '2008'],
#  [['Avon', 'IL'], '19629'],
#  [['Avon', 'IN'], '12502'],
#  [['Avon', 'MA'], '4779'],
#  [['Avon', 'ME'], '24148'],
#  [['Avon', 'MN'], '5027'],
#  [['Avon', 'NC'], '13583'],
#  [['Avon', 'OH'], '1497'],
#  [['Avon', 'PA'], '6124'],
#  [['Avondale Estates', 'GA'], '14464'],
#  [['Avondale', 'AZ'], '400'],
#  [['Avondale', 'CO'], '9745'],
#  ...]

# %%
ticker_file = "ticker_list.csv"

tickers_df = pd.read_csv(ticker_file)
tickers_df.head()
# Out:
#                      name       city state ticker quandl_code industry_type
# 0    Cardinal Health Inc.     Dublin    OH    CAH         CAH         Other
# 1       FedEx Corporation    Memphis    TN    FDX         FDX         Other
# 2  Hawaiian Holdings Inc.   Honolulu    HI     HA          HA         Other
# 3   Las Vegas Sands Corp.  Las Vegas    NV    LVS         LVS         Other
# 4    Sanderson Farms Inc.     Laurel    MS   SAFM        SAFM         Other

# %%
city_area_code = []

for each in range(len(tickers_df)):
    current_city = tickers_df.city[each]
    print(f'Current City: {current_city}')
    current_state = tickers_df.state[each]
    print(f'Current State: {current_state}')
    
    for each in cities:
        if current_city == each[0][0] and current_state == each[0][1]:
            city_area_code.append(each[1])
# Out:
# Current City: Dublin
# Current State: OH
# Current City: Memphis
# Current State: TN
# Current City: Honolulu
# Current State: HI
# Current City: Las Vegas
# Current State: NV
# Current City: Laurel
# Current State: MS
# Current City: Chesterbrook
# Current State: PA
# Current City: Indianapolis
# Current State: IN
# Current City: Charlotte
# Current State: NC
# Current City: Louisville
# Current State: KY
# Current City: Des Moines
# Current State: IA
# Current City: Cupertino
# Current State: CA
# Current City: Seattle
# Current State: WA
# Current City: Bethesda
# Current State: MD
# Current City: New York
# Current State: NY
# Current City: Irving
# Current State: TX
# Current City: Woonsocket
# Current State: RI
# Current City: Atlanta
# Current State: GA
# Current City: Beaverton
# Current State: OR
# Current City: Deerfield
# Current State: IL
# Current City: Bentonville
# Current State: AR

# %%
tickers_df["area_code"] = city_area_code
tickers_df.head()
# Out:
#                      name       city state ticker quandl_code industry_type  \
# 0    Cardinal Health Inc.     Dublin    OH    CAH         CAH         Other
# 1       FedEx Corporation    Memphis    TN    FDX         FDX         Other
# 2  Hawaiian Holdings Inc.   Honolulu    HI     HA          HA         Other
# 3   Las Vegas Sands Corp.  Las Vegas    NV    LVS         LVS         Other
# 4    Sanderson Farms Inc.     Laurel    MS   SAFM        SAFM         Other
#
#   area_code
# 0       948
# 1        12
# 2        34
# 3         5
# 4     12171

# %%
tickers_df.to_csv("ticker_list_areacode.csv", index=False, header=True)
